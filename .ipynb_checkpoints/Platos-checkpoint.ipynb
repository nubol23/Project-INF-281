# %%
import pandas as pd

# %%
df = pd.read_csv('/home/nubol23/Desktop/ExpoGruposDeEstudio/demo_sw/Data/recetas_limpias.csv', index_col=0)

# %%
print(df.shape)

df.head()
# Out:
# (36, 4)
#                                                        nombre  \
# Unnamed: 0
# 0                                              Asado al Horno
# 1                                  Batido de Pina y Frutillas
# 2                                          Ensalada Veraniega
# 3                                       Carpaccio de Verduras
# 4           Lomo Vetado a la Pimienta con Trilogia de Cham...
#
#                                                          link  \
# Unnamed: 0
# 0              https://www.gourmet.cl/recetas/asado-al-horno/
# 1           https://www.gourmet.cl/recetas/batido-de-pina-...
# 2           https://www.gourmet.cl/recetas/ensalada-verani...
# 3           https://www.gourmet.cl/recetas/carpaccio-de-ve...
# 4           https://www.gourmet.cl/recetas/lomo-vetado-a-l...
#
#                                                  ingredientes  \
# Unnamed: 0
# 0           ['1.2 kilos de carne de vacuno (lomo, abastero...
# ...

# %%
plato = df.iloc[4]

# %%
plato
# Out:
# nombre          Lomo Vetado a la Pimienta con Trilogia de Cham...
# link            https://www.gourmet.cl/recetas/lomo-vetado-a-l...
# ingredientes    ['800gr de lomo vetado', '200gr de champinones...
# preparacion     limpiar y dividir la carne en 4 pedazos iguale...
# Name: 4, dtype: object

# %%
plato['preparacion']
# Out:
# 'limpiar y dividir la carne en 4 pedazos iguales.  cortar los champinones paris en cuartos. cortar los champinones ostra en tiras largas, eliminando la parte mas dura del tallo. cortar los champinones shiitake en cuartos, eliminando el tallo. reservar.  calentar un sarten con un poco de aceite y sofreir la cebolla junto con el ajo hasta dorar. luego, agregar los champinones paris y dorar.  enseguida agregar los champinones shiitake y al final los champinones ostra. condimentar con el mix pimientas gourmet y sal a gusto. agregar el perejil deshidratado gourmet y tomillo gourmet. reservar caliente.  condimentar los bifes de lomo vetado por ambos lados con abundante mix de pimientas gourmet y sal. en un sarten a fuego alto poner la carne y sellar por todos lados. poner los pedazos de carne al horno a 180oc por unos minutos hasta obtener el punto de coccion deseado.  preparar el pure: cortar las papas en pedazos del  mismo tamano. y ponerlos en una olla con agua y sal. el agua debe cubri
# ...

# %%
# Dish
name='', preparation='', imagePath='')
# Out:
#   File "<ipython-input-8-3b54acffc8c8>", line 2
#     name='', preparation='', imagePath='')
#                                          ^
# SyntaxError: invalid syntax

# %%
','.join( eval(plato['ingredientes']) )
# Out:
# '800gr de lomo vetado,200gr de champinones paris,200gr champinones ostra,200gr champinones shiitake,2 cdas de aceite de oliva,1 cebolla cortada en cuadraditos,1 diente de ajo picado fino,2 cdas de mix pimientas gourmet,1 cdta de perejil deshidratado gourmet,1/2 cdta de tomillo gourmet,sal a gusto,1 kilo de papas,2 cdas de mantequilla,leche necesaria,1 1/2 cdas de pesto gourmet'

# %%
# Ingredient
# name='', unitaryPrice=)
Ingredient.objects.create(name='', unitaryPrice=-1)

# %%
# DishIngredient
#  = DishIngredients(quantity=, unit='', dish=, ingredient=)
DishIngredients(quantity=, unit='', dish=, ingredient=).save()

# %%
added_ingredients = ['Carne Vacuna', 'Aji de Color', 'Pimienta Negra', 'Ajo', 'Aceite', 'Papa']

# %% [markdown]
# # Batch

# %%
for i, row in df.iterrows():
    if i == 7:
        print('##########Hasta Aquí LLegué##########')
        print()
    print(row['nombre'].upper())
    for ingrediente in eval(row['ingredientes']):
        print(ingrediente)
    print('_'*50)
# Out:
# ASADO AL HORNO
# 1.2 kilos de carne de vacuno (lomo, abastero, choclillo)
# 2 cucharaditas de aji de color gourmet
# 1 cucharadita de pimienta negra molida gourmet
# 1 cucharadita de ajo puro gourmet.
# 1/2 taza de aceite.
# 4 papas peladas
# __________________________________________________
# BATIDO DE PINA Y FRUTILLAS
# 2 rodajas gruesas de pina
# 3 frutillas lavadas sin hojas
# 2 cucharadas de yogurt natural
# 4 cucharadas de salsa de frambuesa gourmet
# 1 cucharada de azucar (opcional)
# 3/4 taza de agua
# __________________________________________________
# ENSALADA VERANIEGA
# 6 tazas de lechugas variadas
# 2 tazas de frutillas laminadas
# 1 taza de queso de cabra cortado en cubos
# 1 cucharada de azucar
# 1 cucharada de mostaza dijon
# 1 cucharadita de sal
#  1/4   taza de vinagre de manzana
#  1/2  taza de aceite de maravilla
# 1 cucharadita de cebolla en polvo gourmet
# 2 cucharada de semillas de amapola
# 1/3 taza de azucar granulada
# 2  1/2  cucharadas de azucar rubia
# ...
